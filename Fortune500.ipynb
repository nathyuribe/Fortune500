# %% [markdown]
# • Prepare a structured dataset that includes the following fields, where available:
# o Company name: Name of the company
# o Country: country in which the company has its main headquarters
# o Industry: Industry classification based on your source
# o Year(s): Year(s) associated with the financial value; please extract the most recent 3
# years of the companies’ financials, if available
# o Revenue: Revenue figure
# o Revenue unit: Unit or currency of the revenue
# o (Optional: Add 3–5 additional KPIs of your choice in the same manner as for Revenue.)
# • Please ensure that the dataset contains at least 100 companies and no more than 500
# companies.

# %%
#!pip install kaggle

# %%
#!pip install kagglehub[pandas-datasets]

# %% [markdown]
# Before the next step I set up the kaggle API with my token:
#
# export KAGGLE_API_TOKEN=<--Token-->
#
# kaggle competitions list  // this helped me check if the api was working

# %%
#!kaggle datasets download -d rm1000/fortune-500-companies

# %%
#!unzip fortune-500-companies.zip

# %% [markdown]
# Firsy Look at the database

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter
import pandas as pd

file_path = "/home/nathalia-uribe/Documentos/NATHY 2.0/LEARNING/Networks/Ejercicios Libro/Fortune 500 Companies.csv"

fortune500df = pd.read_csv(file_path)

print("First 5 records:", fortune500df.head())
# Out:
# First 5 records:                          name  rank  year                industry sector  \
# 0  General Motors Corporation     1  1996  Motor Vehicles & Parts    NaN
# 1          Ford Motor Company     2  1996  Motor Vehicles & Parts    NaN
# 2           Exxon Corporation     3  1996      Petroleum Refining    NaN
# 3       Wal-Mart Stores, Inc.     4  1996   General Merchandisers    NaN
# 4                  AT&T Corp.     5  1996      Telecommunications    NaN
#
#   headquarters_state headquarters_city  market_value_mil  revenue_mil  \
# 0                 MI               NaN               NaN     168828.6
# 1                 MI               NaN               NaN     137137.0
# 2                 TX               NaN               NaN     110009.0
# 3                 AR               NaN               NaN      93627.0
# 4                 NY               NaN               NaN      79609.0
#
#    profit_mil  asset_mil  employees founder_is_ceo female_ceo  \
# 0         NaN        NaN        NaN            NaN        NaN
# 1         NaN        NaN        NaN            NaN        NaN
# 2         NaN        NaN        NaN            NaN        NaN
# 3         NaN        NaN        NaN            NaN        NaN
# 4         NaN        NaN        NaN            NaN        NaN
#
#   newcomer_to_fortune_500 global_500
# 0                     NaN        NaN
# 1                     NaN        NaN
# 2                     NaN        NaN
# 3                     NaN        NaN
# 4                     NaN        NaN

# %% [markdown]
# Checking what metrics are easier to obtain

# %%
fortune500df.isnull().mean()
# Out:
# name                       0.000000
# rank                       0.000000
# year                       0.000000
# industry                   0.000000
# sector                     0.677188
# headquarters_state         0.000000
# headquarters_city          0.462339
# market_value_mil           0.628049
# revenue_mil                0.000000
# profit_mil                 0.605667
# asset_mil                  0.605452
# employees                  0.677188
# founder_is_ceo             0.677188
# female_ceo                 0.677188
# newcomer_to_fortune_500    0.677188
# global_500                 0.713056
# dtype: float64

# %% [markdown]
# Dropping every column that is not needed for the assignment

# %%
f500_clean = fortune500df.drop(columns=['founder_is_ceo', 'female_ceo', 'newcomer_to_fortune_500', 'global_500','rank'])

# %%
f500_clean.head()
# Out:
#                          name  year                industry sector  \
# 0  General Motors Corporation  1996  Motor Vehicles & Parts    NaN
# 1          Ford Motor Company  1996  Motor Vehicles & Parts    NaN
# 2           Exxon Corporation  1996      Petroleum Refining    NaN
# 3       Wal-Mart Stores, Inc.  1996   General Merchandisers    NaN
# 4                  AT&T Corp.  1996      Telecommunications    NaN
#
#   headquarters_state headquarters_city  market_value_mil  revenue_mil  \
# 0                 MI               NaN               NaN     168828.6
# 1                 MI               NaN               NaN     137137.0
# 2                 TX               NaN               NaN     110009.0
# 3                 AR               NaN               NaN      93627.0
# 4                 NY               NaN               NaN      79609.0
#
#    profit_mil  asset_mil  employees
# 0         NaN        NaN        NaN
# 1         NaN        NaN        NaN
# 2         NaN        NaN        NaN
# 3         NaN        NaN        NaN
# 4         NaN        NaN        NaN

# %% [markdown]
# Checking how many unique companies I have

# %%
f500_clean['name'].nunique()
# Out:
# 2255

# %% [markdown]
# Dropping more companies by suitability of the name, i deleted every name that is numeric only, is punctuation only, is too short (like single letters).
# Plus all the rows of companies that don't have available the information that i need like sector, city or state.

# %%
f500_clean = f500_clean.dropna(subset=['name'])

valid_names= r'^[A-Za-z]{2,}.*$'
f500_clean = f500_clean[f500_clean['name'].str.match(valid_names, na=False)]

f500_clean = f500_clean.dropna(subset=['sector'])


f500_clean = f500_clean.dropna(subset=['headquarters_city'])

f500_clean = f500_clean.dropna(subset=['headquarters_state'])

# %% [markdown]
# Checking how many companies I still have...

# %%
f500_clean['name'].nunique()
# Out:
# 745

# %%
f500_clean.head()
# Out:
#                     name  year                                  industry  \
# 9440             Walmart  2015                     General Merchandisers
# 9441         Exxon Mobil  2015                        Petroleum Refining
# 9442             Chevron  2015                        Petroleum Refining
# 9443  Berkshire Hathaway  2015  Insurance: Property and Casualty (Stock)
# 9444               Apple  2015               Computers, Office Equipment
#
#           sector headquarters_state headquarters_city  market_value_mil  \
# 9440   Retailing                 AR       Bentonville          265344.0
# 9441      Energy                 TX            Irving          356549.0
# 9442      Energy                 CA         San Ramon          197381.0
# 9443  Financials                 NE             Omaha          357344.0
# 9444  Technology                 CA         Cupertino          724773.0
#
#       revenue_mil  profit_mil  asset_mil  employees
# 9440     485651.0     16363.0   203706.0  2200000.0
# 9441     382597.0     32520.0   349493.0    83700.0
# 9442     203784.0     19241.0   266026.0    64700.0
# 9443     194673.0     19872.0   526186.0   316000.0
# 9444     182795.0     39510.0   231839.0    97200.0

# %% [markdown]
# Adding the count of years with market value ...

# %%
f500_clean['num_years'] = f500_clean.groupby('name')['year'].transform('nunique')

# %% [markdown]
# Ordering by name and years , so i see them in order

# %%
f500_clean.sort_values(["name", "year"], ascending=[True, False])
# Out:
#                  name  year                          industry  \
# 13914  ABM Industries  2023  Diversified Outsourcing Services
# 12901  ABM Industries  2021  Diversified Outsourcing Services
# 12401  ABM Industries  2020  Diversified Outsourcing Services
# 11902  ABM Industries  2019  Diversified Outsourcing Services
# 11437  ABM Industries  2018  Diversified Outsourcing Services
# ...               ...   ...                               ...
# 11679  salesforce.com  2019                 Computer Software
# 11224  salesforce.com  2018                 Computer Software
# 10765  salesforce.com  2017                 Computer Software
# 10325  salesforce.com  2016                 Computer Software
# 9922   salesforce.com  2015                 Computer Software
#
#                   sector headquarters_state headquarters_city  \
# 13914  Business Services                 NY          New York
# 12901  Business Services                 NY          New York
# 12401  Business Services                 NY          New York
# 11902  Business Services                 NY          New York
# 11437  Business Services                 NY          New York
# ...                  ...                ...               ...
# 11679         Technology                 CA     San Francisco
# 11224         Technology                 CA     San Francisco
# 10765         Technology                 CA     San Francisco
# 10325         Technology                 CA     San Francisco
# 9922          Technology                 CA     San Francisco
#
#        market_value_mil  revenue_mil  profit_mil  asset_mil  employees  \
# 13914            2971.0       7807.0       230.0     4869.0   127000.0
# 12901            3422.0       5988.0         0.0     3777.0   114000.0
# 12401            1623.0       6499.0       127.0     3693.0   140000.0
# 11902            2408.0       6442.0        98.0     3628.0   140000.0
# 11437            2200.0       5454.0         4.0     3813.0   140000.0
# ...                 ...          ...         ...        ...        ...
# 11679          122103.0      13282.0      1110.0    30737.0    35000.0
# 11224           85074.0      10480.0       128.0    21010.0    29000.0
# 10765           58362.0       8392.0       180.0    17585.0    25000.0
# 10325           49533.0       6667.0        47.0    12771.0    19742.0
# 9922            43467.0       5374.0      -263.0    10693.0    16200.0
#
#        num_years
# 13914          7
# 12901          7
# 12401          7
# 11902          7
# 11437          7
# ...          ...
# 11679          5
# 11224          5
# 10765          5
# 10325          5
# 9922           5
#
# [4362 rows x 12 columns]

# %% [markdown]
# Creating a copy of the table without companies that have less than 2 years.....

# %%
f500_clean= f500_clean[f500_clean['num_years'] >= 3].copy()

# %% [markdown]
# Checking how many companies I still have...

# %%
f500_clean['name'].nunique()
# Out:
# 588

# %%
f500_clean.sort_values(["name", "year"], ascending=[True, False])
# Out:
#                  name  year                          industry  \
# 13914  ABM Industries  2023  Diversified Outsourcing Services
# 12901  ABM Industries  2021  Diversified Outsourcing Services
# 12401  ABM Industries  2020  Diversified Outsourcing Services
# 11902  ABM Industries  2019  Diversified Outsourcing Services
# 11437  ABM Industries  2018  Diversified Outsourcing Services
# ...               ...   ...                               ...
# 11679  salesforce.com  2019                 Computer Software
# 11224  salesforce.com  2018                 Computer Software
# 10765  salesforce.com  2017                 Computer Software
# 10325  salesforce.com  2016                 Computer Software
# 9922   salesforce.com  2015                 Computer Software
#
#                   sector headquarters_state headquarters_city  \
# 13914  Business Services                 NY          New York
# 12901  Business Services                 NY          New York
# 12401  Business Services                 NY          New York
# 11902  Business Services                 NY          New York
# 11437  Business Services                 NY          New York
# ...                  ...                ...               ...
# 11679         Technology                 CA     San Francisco
# 11224         Technology                 CA     San Francisco
# 10765         Technology                 CA     San Francisco
# 10325         Technology                 CA     San Francisco
# 9922          Technology                 CA     San Francisco
#
#        market_value_mil  revenue_mil  profit_mil  asset_mil  employees  \
# 13914            2971.0       7807.0       230.0     4869.0   127000.0
# 12901            3422.0       5988.0         0.0     3777.0   114000.0
# 12401            1623.0       6499.0       127.0     3693.0   140000.0
# 11902            2408.0       6442.0        98.0     3628.0   140000.0
# 11437            2200.0       5454.0         4.0     3813.0   140000.0
# ...                 ...          ...         ...        ...        ...
# 11679          122103.0      13282.0      1110.0    30737.0    35000.0
# 11224           85074.0      10480.0       128.0    21010.0    29000.0
# 10765           58362.0       8392.0       180.0    17585.0    25000.0
# 10325           49533.0       6667.0        47.0    12771.0    19742.0
# 9922            43467.0       5374.0      -263.0    10693.0    16200.0
#
#        num_years
# 13914          7
# 12901          7
# 12401          7
# 11902          7
# 11437          7
# ...          ...
# 11679          5
# 11224          5
# 10765          5
# 10325          5
# 9922           5
#
# [4137 rows x 12 columns]

# %% [markdown]
# Ordering my table and dropping the bottom 88 companies with less years .... Since I have 588 companies with all the information I need , then I'll drop the ones that have been on the list for the least years

# %%
f500_clean = f500_clean.sort_values(by='num_years', ascending=False)

company_years = f500_clean[['name', 'num_years']].drop_duplicates()
companies_to_drop = company_years.sort_values(by='num_years').head(88)['name']
f500_clean = f500_clean[~f500_clean['name'].isin(companies_to_drop)].copy()
f500_clean.head()
# Out:
#                      name  year                                  industry  \
# 13925  Genworth Financial  2023           Insurance: Life, Health (Stock)
# 9440              Walmart  2015                     General Merchandisers
# 9441          Exxon Mobil  2015                        Petroleum Refining
# 9442              Chevron  2015                        Petroleum Refining
# 9443   Berkshire Hathaway  2015  Insurance: Property and Casualty (Stock)
#
#            sector headquarters_state headquarters_city  market_value_mil  \
# 13925  Financials                 VA          Richmond            2477.0
# 9440    Retailing                 AR       Bentonville          265344.0
# 9441       Energy                 TX            Irving          356549.0
# 9442       Energy                 CA         San Ramon          197381.0
# 9443   Financials                 NE             Omaha          357344.0
#
#        revenue_mil  profit_mil  asset_mil  employees  num_years
# 13925       7507.0       609.0    86442.0     2500.0          9
# 9440      485651.0     16363.0   203706.0  2200000.0          9
# 9441      382597.0     32520.0   349493.0    83700.0          9
# 9442      203784.0     19241.0   266026.0    64700.0          9
# 9443      194673.0     19872.0   526186.0   316000.0          9

# %%
f500_clean['name'].nunique()
# Out:
# 500

# %% [markdown]
# Adding extra columns , as requested with the currency/ metrics  AND also country since the data set I found had the city of headquarters but not the country. The state and city were left intentionally... for clarity, that ineed all headquarters are in the US.

# %%
f500_clean['country'] = 'USA'
f500_clean['market_value_currency'] = 'USD'
f500_clean['revenue_currency'] = 'USD'
f500_clean['profit_currency'] = 'USD'
f500_clean['asset_currency'] = 'USD'
f500_clean['employees_metric'] = 'employees'
f500_clean.sort_values(["name", "year"], ascending=[True, False])
# Out:
#                  name  year                          industry  \
# 13914  ABM Industries  2023  Diversified Outsourcing Services
# 12901  ABM Industries  2021  Diversified Outsourcing Services
# 12401  ABM Industries  2020  Diversified Outsourcing Services
# 11902  ABM Industries  2019  Diversified Outsourcing Services
# 11437  ABM Industries  2018  Diversified Outsourcing Services
# ...               ...   ...                               ...
# 11679  salesforce.com  2019                 Computer Software
# 11224  salesforce.com  2018                 Computer Software
# 10765  salesforce.com  2017                 Computer Software
# 10325  salesforce.com  2016                 Computer Software
# 9922   salesforce.com  2015                 Computer Software
#
#                   sector headquarters_state headquarters_city  \
# 13914  Business Services                 NY          New York
# 12901  Business Services                 NY          New York
# 12401  Business Services                 NY          New York
# 11902  Business Services                 NY          New York
# 11437  Business Services                 NY          New York
# ...                  ...                ...               ...
# 11679         Technology                 CA     San Francisco
# 11224         Technology                 CA     San Francisco
# 10765         Technology                 CA     San Francisco
# 10325         Technology                 CA     San Francisco
# 9922          Technology                 CA     San Francisco
#
#        market_value_mil  revenue_mil  profit_mil  asset_mil  employees  \
# 13914            2971.0       7807.0       230.0     4869.0   127000.0
# 12901            3422.0       5988.0         0.0     3777.0   114000.0
# 12401            1623.0       6499.0       127.0     3693.0   140000.0
# 11902            2408.0       6442.0        98.0     3628.0   140000.0
# 11437            2200.0       5454.0         4.0     3813.0   140000.0
# ...                 ...          ...         ...        ...        ...
# 11679          122103.0      13282.0      1110.0    30737.0    35000.0
# 11224           85074.0      10480.0       128.0    21010.0    29000.0
# 10765           58362.0       8392.0       180.0    17585.0    25000.0
# 10325           49533.0       6667.0        47.0    12771.0    19742.0
# 9922            43467.0       5374.0      -263.0    10693.0    16200.0
#
#        num_years country market_value_currency revenue_currency  \
# 13914          7     USA                   USD              USD
# 12901          7     USA                   USD              USD
# 12401          7     USA                   USD              USD
# 11902          7     USA                   USD              USD
# 11437          7     USA                   USD              USD
# ...          ...     ...                   ...              ...
# 11679          5     USA                   USD              USD
# 11224          5     USA                   USD              USD
# 10765          5     USA                   USD              USD
# 10325          5     USA                   USD              USD
# 9922           5     USA                   USD              USD
#
#       profit_currency asset_currency employees_metric
# 13914             USD            USD        employees
# 12901             USD            USD        employees
# 12401             USD            USD        employees
# 11902             USD            USD        employees
# 11437             USD            USD        employees
# ...               ...            ...              ...
# 11679             USD            USD        employees
# 11224             USD            USD        employees
# 10765             USD            USD        employees
# 10325             USD            USD        employees
# 9922              USD            USD        employees
#
# [3843 rows x 18 columns]

# %% [markdown]
# Ordering the columns

# %%
f500_clean = f500_clean[
    ['name','num_years','year','industry','sector','country','headquarters_state','headquarters_city',
     'market_value_mil','market_value_currency','revenue_mil','revenue_currency',
     'profit_mil','profit_currency','asset_mil','asset_currency','employees',
     'employees_metric']
]

f500_clean.sort_values(["name", "year"], ascending=[True, False])
# Out:
#                  name  num_years  year                          industry  \
# 13914  ABM Industries          7  2023  Diversified Outsourcing Services
# 12901  ABM Industries          7  2021  Diversified Outsourcing Services
# 12401  ABM Industries          7  2020  Diversified Outsourcing Services
# 11902  ABM Industries          7  2019  Diversified Outsourcing Services
# 11437  ABM Industries          7  2018  Diversified Outsourcing Services
# ...               ...        ...   ...                               ...
# 11679  salesforce.com          5  2019                 Computer Software
# 11224  salesforce.com          5  2018                 Computer Software
# 10765  salesforce.com          5  2017                 Computer Software
# 10325  salesforce.com          5  2016                 Computer Software
# 9922   salesforce.com          5  2015                 Computer Software
#
#                   sector country headquarters_state headquarters_city  \
# 13914  Business Services     USA                 NY          New York
# 12901  Business Services     USA                 NY          New York
# 12401  Business Services     USA                 NY          New York
# 11902  Business Services     USA                 NY          New York
# 11437  Business Services     USA                 NY          New York
# ...                  ...     ...                ...               ...
# 11679         Technology     USA                 CA     San Francisco
# 11224         Technology     USA                 CA     San Francisco
# 10765         Technology     USA                 CA     San Francisco
# 10325         Technology     USA                 CA     San Francisco
# 9922          Technology     USA                 CA     San Francisco
#
#        market_value_mil market_value_currency  revenue_mil revenue_currency  \
# 13914            2971.0                   USD       7807.0              USD
# 12901            3422.0                   USD       5988.0              USD
# 12401            1623.0                   USD       6499.0              USD
# 11902            2408.0                   USD       6442.0              USD
# 11437            2200.0                   USD       5454.0              USD
# ...                 ...                   ...          ...              ...
# 11679          122103.0                   USD      13282.0              USD
# 11224           85074.0                   USD      10480.0              USD
# 10765           58362.0                   USD       8392.0              USD
# 10325           49533.0                   USD       6667.0              USD
# 9922            43467.0                   USD       5374.0              USD
#
#        profit_mil profit_currency  asset_mil asset_currency  employees  \
# 13914       230.0             USD     4869.0            USD   127000.0
# 12901         0.0             USD     3777.0            USD   114000.0
# 12401       127.0             USD     3693.0            USD   140000.0
# 11902        98.0             USD     3628.0            USD   140000.0
# 11437         4.0             USD     3813.0            USD   140000.0
# ...           ...             ...        ...            ...        ...
# 11679      1110.0             USD    30737.0            USD    35000.0
# 11224       128.0             USD    21010.0            USD    29000.0
# 10765       180.0             USD    17585.0            USD    25000.0
# 10325        47.0             USD    12771.0            USD    19742.0
# 9922       -263.0             USD    10693.0            USD    16200.0
#
#       employees_metric
# 13914        employees
# 12901        employees
# 12401        employees
# 11902        employees
# 11437        employees
# ...                ...
# 11679        employees
# 11224        employees
# 10765        employees
# 10325        employees
# 9922         employees
#
# [3843 rows x 18 columns]

# %% [markdown]
# Filtering the years to keep the 3 most recent only

# %%
Final_Fortune_500 = f500_clean.groupby('name', group_keys=False).apply(lambda x: x.nlargest(3, 'year'))
Final_Fortune_500.sort_values(["name", "year"], ascending=[True, False])
# Out:
# /tmp/ipykernel_5869/3197569287.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   Final_Fortune_500 = f500_clean.groupby('name', group_keys=False).apply(lambda x: x.nlargest(3, 'year'))
#                  name  num_years  year                          industry  \
# 13914  ABM Industries          7  2023  Diversified Outsourcing Services
# 12901  ABM Industries          7  2021  Diversified Outsourcing Services
# 12401  ABM Industries          7  2020  Diversified Outsourcing Services
# 13749           AECOM          9  2023        Engineering & Construction
# 13199           AECOM          9  2022        Engineering & Construction
# ...               ...        ...   ...                               ...
# 11391     iHeartMedia          5  2018                     Entertainment
# 10865     iHeartMedia          5  2017                     Entertainment
# 11679  salesforce.com          5  2019                 Computer Software
# 11224  salesforce.com          5  2018                 Computer Software
# 10765  salesforce.com          5  2017                 Computer Software
#
#                            sector country headquarters_state  \
# 13914           Business Services     USA                 NY
# 12901           Business Services     USA                 NY
# 12401           Business Services     USA                 NY
# 13749  Engineering & Construction     USA                 TX
# 13199  Engineering & Construction     USA                 TX
# ...                           ...     ...                ...
# 11391                       Media     USA                 TX
# 10865                       Media     USA                 TX
# 11679                  Technology     USA                 CA
# 11224                  Technology     USA                 CA
# 10765                  Technology     USA                 CA
#
#       headquarters_city  market_value_mil market_value_currency  revenue_mil  \
# 13914          New York            2971.0                   USD       7807.0
# 12901          New York            3422.0                   USD       5988.0
# 12401          New York            1623.0                   USD       6499.0
# 13749            Dallas           11716.0                   USD      13496.0
# 13199            Dallas           10857.0                   USD      14112.0
# ...                 ...               ...                   ...          ...
# 11391       San Antonio              39.0                   USD       6178.0
# 10865       San Antonio             330.0                   USD       6274.0
# 11679     San Francisco          122103.0                   USD      13282.0
# 11224     San Francisco           85074.0                   USD      10480.0
# 10765     San Francisco           58362.0                   USD       8392.0
#
#       revenue_currency  profit_mil profit_currency  asset_mil asset_currency  \
# 13914              USD       230.0             USD     4869.0            USD
# 12901              USD         0.0             USD     3777.0            USD
# 12401              USD       127.0             USD     3693.0            USD
# 13749              USD       311.0             USD    11139.0            USD
# 13199              USD       173.0             USD    11734.0            USD
# ...                ...         ...             ...        ...            ...
# 11391              USD       704.0             USD    12257.0            USD
# 10865              USD       296.0             USD    12862.0            USD
# 11679              USD      1110.0             USD    30737.0            USD
# 11224              USD       128.0             USD    21010.0            USD
# 10765              USD       180.0             USD    17585.0            USD
#
#        employees employees_metric
# 13914   127000.0        employees
# 12901   114000.0        employees
# 12401   140000.0        employees
# 13749    50000.0        employees
# 13199    51000.0        employees
# ...          ...              ...
# 11391    18700.0        employees
# 10865    18700.0        employees
# 11679    35000.0        employees
# 11224    29000.0        employees
# 10765    25000.0        employees
#
# [1500 rows x 18 columns]

# %% [markdown]
# Grouping the rows by 'name', 'num_years', 'industry', 'sector', 'country', 'headquarters_state', 'headquarters_city'.
#
# And here is the result:

# %%
group_cols = ['name', 'num_years', 'industry', 'sector', 'country', 'headquarters_state', 'headquarters_city']
Final_Fortune_500 = Final_Fortune_500.groupby(group_cols).agg(list).reset_index()
Final_Fortune_500.sort_values(["num_years"], ascending=[False])
# Out:
#                   name  num_years                         industry  \
# 530               eBay          9  Internet Services and Retailing
# 512    Western Digital          9      Computers, Office Equipment
# 510           WestRock          9            Packaging, Containers
# 509        Wells Fargo          9                 Commercial Banks
# 506   Waste Management          9                 Waste Management
# ..                 ...        ...                              ...
# 472   Truist Financial          4                 Commercial Banks
# 76   Bath & Body Works          4       Specialty Retailers: Other
# 490   Univar Solutions          4         Wholesalers: Diversified
# 499             Vistra          4                           Energy
# 27              Amazon          4  Internet Services and Retailing
#
#                 sector country headquarters_state headquarters_city  \
# 530         Technology     USA                 CA          San Jose
# 512         Technology     USA                 CA          San Jose
# 510          Materials     USA                 GA           Atlanta
# 509         Financials     USA                 CA     San Francisco
# 506  Business Services     USA                 TX           Houston
# ..                 ...     ...                ...               ...
# 472         Financials     USA                 NC         Charlotte
# 76           Retailing     USA                 OH          Columbus
# 490        Wholesalers     USA                 IL     Downers Grove
# 499             Energy     USA                 TX            Irving
# 27           Retailing     USA                 WA           Seattle
#
#                    year                   market_value_mil  \
# 530  [2023, 2022, 2021]        [23821.0, 33642.0, 41671.0]
# 512  [2023, 2022, 2021]        [12029.0, 15536.0, 20432.0]
# 510  [2023, 2022, 2021]         [7759.0, 12379.0, 13716.0]
# 509  [2023, 2022, 2021]     [141188.0, 184225.0, 161521.0]
# 506  [2023, 2022, 2021]        [66372.0, 65803.0, 54452.0]
# ..                  ...                                ...
# 472  [2023, 2022, 2021]        [45290.0, 75354.0, 78409.0]
# 76         [2023, 2022]                  [8368.0, 11420.0]
# 490  [2023, 2022, 2021]           [5521.0, 5460.0, 3651.0]
# 499  [2023, 2022, 2021]          [9155.0, 10435.0, 8512.0]
# 27   [2023, 2022, 2021]  [1058440.0, 1658807.0, 1558070.0]
#
#     market_value_currency                     revenue_mil revenue_currency  \
# 530       [USD, USD, USD]      [9795.0, 12394.0, 11351.0]  [USD, USD, USD]
# 512       [USD, USD, USD]     [18793.0, 16922.0, 16736.0]  [USD, USD, USD]
# 510       [USD, USD, USD]     [21257.0, 18746.0, 17579.0]  [USD, USD, USD]
# 509       [USD, USD, USD]     [82859.0, 82407.0, 80303.0]  [USD, USD, USD]
# 506       [USD, USD, USD]     [19698.0, 17931.0, 15218.0]  [USD, USD, USD]
# ..                    ...                             ...              ...
# 472       [USD, USD, USD]     [25356.0, 23064.0, 24427.0]  [USD, USD, USD]
# 76             [USD, USD]                [7560.0, 7882.0]       [USD, USD]
# 490       [USD, USD, USD]       [11475.0, 9536.0, 8265.0]  [USD, USD, USD]
# 499       [USD, USD, USD]     [13728.0, 12077.0, 11443.0]  [USD, USD, USD]
# 27        [USD, USD, USD]  [513983.0, 469822.0, 386064.0]  [USD, USD, USD]
#
#                      profit_mil  profit_currency  \
# 530   [1269.0, 13608.0, 5667.0]  [USD, USD, USD]
# 512      [1500.0, 821.0, 250.0]  [USD, USD, USD]
# 510       [945.0, 838.0, 691.0]  [USD, USD, USD]
# 509  [13182.0, 21548.0, 3301.0]  [USD, USD, USD]
# 506    [2238.0, 1816.0, 1496.0]  [USD, USD, USD]
# ..                          ...              ...
# 472    [6260.0, 6440.0, 4482.0]  [USD, USD, USD]
# 76              [800.0, 1334.0]       [USD, USD]
# 490        [545.0, 461.0, 53.0]  [USD, USD, USD]
# 499     [1227.0, 1274.0, 636.0]  [USD, USD, USD]
# 27   [2722.0, 33364.0, 21331.0]  [USD, USD, USD]
#
#                              asset_mil   asset_currency  \
# 530        [20850.0, 26626.0, 19310.0]  [USD, USD, USD]
# 512        [26259.0, 26132.0, 25662.0]  [USD, USD, USD]
# 510        [28406.0, 29254.0, 28780.0]  [USD, USD, USD]
# 509  [1881016.0, 1948068.0, 1955163.0]  [USD, USD, USD]
# 506        [31367.0, 29097.0, 29345.0]  [USD, USD, USD]
# ..                                 ...              ...
# 472     [555255.0, 541241.0, 509228.0]  [USD, USD, USD]
# 76                    [5494.0, 6026.0]       [USD, USD]
# 490           [7146.0, 6778.0, 6355.0]  [USD, USD, USD]
# 499        [32787.0, 29683.0, 25208.0]  [USD, USD, USD]
# 27      [462675.0, 420549.0, 321195.0]  [USD, USD, USD]
#
#                              employees                   employees_metric
# 530        [11600.0, 10800.0, 12700.0]  [employees, employees, employees]
# 512        [65000.0, 65600.0, 63800.0]  [employees, employees, employees]
# 510        [50500.0, 49900.0, 49300.0]  [employees, employees, employees]
# 509     [238000.0, 247848.0, 268531.0]  [employees, employees, employees]
# 506        [49500.0, 48500.0, 48250.0]  [employees, employees, employees]
# ..                                 ...                                ...
# 472        [53987.0, 51462.0, 53638.0]  [employees, employees, employees]
# 76                  [33000.0, 32850.0]             [employees, employees]
# 490           [9746.0, 9450.0, 9457.0]  [employees, employees, employees]
# 499           [4910.0, 5060.0, 5365.0]  [employees, employees, employees]
# 27   [1541000.0, 1608000.0, 1298000.0]  [employees, employees, employees]
#
# [533 rows x 18 columns]

# %%
Final_Fortune_500.isnull().mean()
# Out:
# name                     0.0
# num_years                0.0
# industry                 0.0
# sector                   0.0
# country                  0.0
# headquarters_state       0.0
# headquarters_city        0.0
# year                     0.0
# market_value_mil         0.0
# market_value_currency    0.0
# revenue_mil              0.0
# revenue_currency         0.0
# profit_mil               0.0
# profit_currency          0.0
# asset_mil                0.0
# asset_currency           0.0
# employees                0.0
# employees_metric         0.0
# dtype: float64

# %%
Final_Fortune_500.to_csv('final_f500.csv', index=False)
